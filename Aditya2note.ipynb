# %%
# diractory of string 
dir (str)

# %%
s = "abcABC123"
u = 0
l = 0
d =0
for i in s:
  if i.isupper():
    u +=1
  elif i.islower():
    l +=1
  else:
    d+=1
print("uppercase:", u, "lowercase:", l, "digits:",d)
# Out:
# uppercase: 3 lowercase: 3 digits: 3

# %%
s = "abc123"
for i in s:
  print(i)
# Out:
# a
# b
# c
# 1
# 2
# 3

# %%
# note we use multiple line of using "element" or """elements"""
s ="abc123"
x = 10
print(len(s))
print(max(s))
print(min(s))
print(str(x))#convert integer to string
# Out:
# 6
# c
# 1
# 10

# %%
# Return  ASCII value of given element
ord ('1')
# Out:
# 49

# %%
a = True
b= False
print(a,b)
# Out:
# True False

# %%
s = "abc"
for i in s:
  print(i)
for i in range(len(s)):
  print(s[i])
# Out:
# a
# b
# c
# a
# b
# c

# %%
s = "abc"
for i in range(len(s)):# show lenth
 print(s[i])            #show index
# Out:
# a
# b
# c

# %%
#print the no of ()

s = input()
print(s.count("()")*2)

# %%
# find out the refrence variable addres
x= 10
y = 20
print(id(x),id(y))
# Out:
# 10914784 10915104

# %%
s ="abc123"
for i in s:
  print(i)
# Out:
# a
# b
# c
# 1
# 2
# 3

# %%
 #count all the upper, lower case and digits in given string.
n=input()
u = 0
l = 0
d = 0
for i  in n:
  if i.isupper():
    u+=1 
  elif i.islower():
    l+=1
  elif i.isdigit():
    d+=1
print("upper Case", u, "lower case",l,"digits",d)
